# %% [markdown]
# # RADICAL-Cybertools: RADICAL-EnTK Tutorial
#
# One has to handle RADICAL-EnTK applications with some care when running them in a Jupyter notebook.  In particular one should avoid to run cells out of order.  It is usually best to cleanly terminate the kernel before rerunning any / all cells.  This notebook thus puts the exercise code into a *single* cell which you can edit freely and then execute.
#
# ## Exercise 1: Change the number of ensemble members (number of pipelines) and number of simulations per pipeline
#   - Your are presumably running on a small resource - be gentle ;-)
#   - Look at the `for` loop in the program's `main` section
#   - Look at the construction of Stage 2 (`s2`)

# %%
import os

mdb_host = os.environ.get('MDB_HOST', 'mongodb')
mdb_port = os.environ.get('MDB_PORT', '27017')
mdb_name = os.environ.get('MDB_USER', 'guest')
mdb_pswd = os.environ.get('MDB_PSWD', 'guest')
mdb_dtbs = os.environ.get('MDB_DTBS', 'default')

# %env RADICAL_PILOT_DBURL=mongodb://$mdb_name:$mdb_pswd@$mdb_host:$mdb_port/$mdb_dtbs

# %env RADICAL_LOG_LVL=OFF
# %env RADICAL_REPORT_ANIME=FALSE

import radical.entk as re


def get_stage_1(sandbox):
    '''
    first stage: create 1 task to generate a random seed number
    '''
    
    s1 = re.Stage()

    t1 = re.Task()
    t1.executable = '/bin/sh'
    t1.arguments  = ['-c', 'od -An -N1 -i /dev/random']
    t1.stdout     = 'random.txt'
    t1.sandbox    = sandbox

    s1.add_tasks(t1)
    return s1


def get_stage_2(sandbox):
    '''
    second stage: create 10 tasks to compute the n'th power of a random seed
    '''
    
    s2 = re.Stage()

    n_simulations = 10
    for i in range(n_simulations):
        t2 = re.Task()
        t2.executable = '/bin/sh'
        t2.arguments  = ['-c', "echo '$(cat random.txt) ^ %d' | bc" % i]
        t2.stdout     = 'power.%03d.txt' % i
        t2.sandbox    = sandbox
        s2.add_tasks(t2)
    
    return s2


def get_stage_3(sandbox):
    '''
    third stage: compute sum over all powers
    '''
    
    s3 = re.Stage()

    t3 = re.Task()
    t3.executable = '/bin/sh'
    t3.arguments  = ['-c', 'cat power.*.txt | paste -sd+ | bc']
    t3.stdout     = 'sum.txt'
    t3.sandbox    = sandbox

    # download the result while renaming to get unique files per pipeline
    t3.download_output_data = ['sum.txt > %s.sum.txt' % sandbox]
    
    s3.add_tasks(t3)
    return s3


def generate_pipeline(uid):
    '''
    Generate a single simulation pipeline, i.e., a new ensemble member.
    The pipeline structure consisting of three steps as described above.
    '''

    # all tasks in this pipeline share the same sandbox
    sandbox = uid

    # assemble three stages into a pipeline and return it
    p = re.Pipeline()
    p.add_stages([get_stage_1(sandbox), 
                  get_stage_2(sandbox), 
                  get_stage_3(sandbox)])

    return p

appman = re.AppManager()

appman.resource_desc = {
    'resource': 'local.localhost_test',
    'walltime': 10,
    'cpus'    : 2
}

n_pipelines = 2

ensemble = set()
for cnt in range(n_pipelines):
    ensemble.add(generate_pipeline(uid='pipe.%03d' % cnt))

appman.workflow = ensemble
appman.run()

for cnt in range(n_pipelines):
    data = open('pipe.%03d.sum.txt' % cnt).read()
    print('%3d -- %25d' % (cnt, int(data)))
# Out:
# EnTK session: re.session.thinkie.merzky.019614.0028
# Creating AppManager
# Setting up ZMQ queues                                                         ok
# env: RADICAL_PILOT_DBURL=mongodb://guest:guest@mongodb:27017/default
# env: RADICAL_PILOT_DBURL=mongodb://am:Mz0PliY3ajLOgj@95.217.193.116:27017/am
# env: RADICAL_LOG_LVL=OFF
# env: RADICAL_REPORT_ANIME=FALSE
# AppManager initialized                                                        ok
# Validating and assigning resource manager                                     ok
# Setting up ZMQ queues                                                        n/a
# new session: [re.session.thinkie.merzky.019614.0028]                           \
# database   : [mongodb://am:****@95.217.193.116:27017/am]                      ok
# create pilot manager                                                          ok
# submit 1 pilot(s)
#         pilot.0000   local.localhost_test      2 cores       0 gpus           ok
# Update: All components created
# pipeline.0002 state: SCHEDULING
# Update: pipeline.0002.stage.0006 state: SCHEDULING
# Update: pipeline.0002.stage.0006.task.000024 state: SCHEDULING
# Update: pipeline.0003 state: SCHEDULING
# Update: pipeline.0003.stage.0009 state: SCHEDULING
# Update: pipeline.0003.stage.0009.task.000036 state: SCHEDULING
# Update: pipeline.0002.stage.0006.task.000024 state: SCHEDULED
# Update: pipeline.0003.stage.0009.task.000036 state: SCHEDULED
# Update: pipeline.0002.stage.0006 state: SCHEDULED
# Update: pipeline.0003.stage.0009 state: SCHEDULED
# create task manager                                                           ok
# submit: ##############Update: pipeline.0002.stage.0006.task.000024 state: SUBMITTING
# ########################################Update: pipeline.0003.stage.0009.task.000036 state: SUBMITTING
# ##################
# Update: pipeline.0002.stage.0006.task.000024 state: DONE
# Update: pipeline.0002.stage.0006 state: DONE
# Update: pipeline.0002.stage.0007 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000032 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000025 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000029 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000033 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000031 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000026 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000028 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000030 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000034 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000027 state: SCHEDULING
# Update: pipeline.0002.stage.0007.task.000032 state: SCHEDULED
# submit: Update: Update: pipeline.0002.stage.0007.task.000025 state: SCHEDULED
# Update: #pipeline.0003.stage.0009.task.000036 state: DONE
# pipeline.0002.stage.0007.task.000032 state: SUBMITTING
# Update: #pipeline.0002.stage.0007.task.000029 state: SCHEDULED
# Update: pipeline.0003.stage.0009 state: DONE
# Update: #pipeline.0002.stage.0007.task.000033 state: SCHEDULED
# #Update: Update: pipeline.0002.stage.0007.task.000031 state: SCHEDULED
# pipeline.0002.stage.0007.task.000025 state: SUBMITTING
# Update: #Update: #pipeline.0002.stage.0007.task.000026 state: SCHEDULED
# pipeline.0002.stage.0007.task.000029 state: SUBMITTING
# Update: #pipeline.0002.stage.0007.task.000028 state: SCHEDULED
# #Update: Update: pipeline.0002.stage.0007.task.000030 state: SCHEDULED
# pipeline.0002.stage.0007.task.000033 state: SUBMITTING
# #Update: #pipeline.0002.stage.0007.task.000034 state: SCHEDULED
# Update: pipeline.0002.stage.0007.task.000031 state: SUBMITTING
# Update: #pipeline.0002.stage.0007.task.000027 state: SCHEDULED
# Update: Update: #pipeline.0002.stage.0007.task.000026 state: SUBMITTING
# pipeline.0002.stage.0007 state: SCHEDULED
# #Update: #pipeline.0003.stage.0010 state: SCHEDULING
# Update: #pipeline.0003.stage.0010.task.000043 state: SCHEDULING
# #Update: pipeline.0003.stage.0010.task.000037 state: SCHEDULING
# #Update: #pipeline.0003.stage.0010.task.000046 state: SCHEDULING
# Update: #pipeline.0003.stage.0010.task.000038 state: SCHEDULING
# #Update: pipeline.0003.stage.0010.task.000045 state: SCHEDULING
# #Update: #pipeline.0003.stage.0010.task.000044 state: SCHEDULING
# Update: #pipeline.0003.stage.0010.task.000042 state: SCHEDULING
# #Update: pipeline.0003.stage.0010.task.000039 state: SCHEDULING
# #Update: #pipeline.0003.stage.0010.task.000040 state: SCHEDULING
# Update: #pipeline.0003.stage.0010.task.000041 state: SCHEDULING
# #Update: Update: pipeline.0003.stage.0010.task.000043 state: SCHEDULED
# pipeline.0002.stage.0007.task.000028 state: SUBMITTING
# #Update: #pipeline.0003.stage.0010.task.000037 state: SCHEDULED
# #Update: Update: #pipeline.0002.stage.0007.task.000030 state: SUBMITTING
# pipeline.0003.stage.0010.task.000046 state: SCHEDULED
# #Update: #pipeline.0003.stage.0010.task.000038 state: SCHEDULED
# Update: #pipeline.0002.stage.0007.task.000034 state: SUBMITTING
# Update: #pipeline.0003.stage.0010.task.000045 state: SCHEDULED
# #Update: Update: #pipeline.0003.stage.0010.task.000044 state: SCHEDULED
# pipeline.0002.stage.0007.task.000027 state: SUBMITTING
# #Update: #####pipeline.0003.stage.0010.task.000042 state: SCHEDULED
# #######Update: Update: #pipeline.0003.stage.0010.task.000039 state: SCHEDULED
# pipeline.0003.stage.0010.task.000043 state: SUBMITTING
# #Update: #pipeline.0003.stage.0010.task.000040 state: SCHEDULED
# Update: #Update: #pipeline.0003.stage.0010.task.000037 state: SUBMITTING
# pipeline.0003.stage.0010.task.000041 state: SCHEDULED
# #Update: #pipeline.0003.stage.0010 state: SCHEDULED
# #####Update: #pipeline.0003.stage.0010.task.000046 state: SUBMITTING
# ########
# submit: ########################################################################
# Update: pipeline.0003.stage.0010.task.000038 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000045 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000044 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000042 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000039 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000040 state: SUBMITTING
# Update: pipeline.0003.stage.0010.task.000041 state: SUBMITTING
# Update: pipeline.0002.stage.0007.task.000032 state: DONE
# Update: pipeline.0002.stage.0007.task.000025 state: DONE
# Update: pipeline.0002.stage.0007.task.000029 state: DONE
# Update: pipeline.0002.stage.0007.task.000033 state: DONE
# Update: pipeline.0002.stage.0007.task.000031 state: DONE
# Update: pipeline.0002.stage.0007.task.000026 state: DONE
# Update: pipeline.0002.stage.0007.task.000028 state: DONE
# Update: pipeline.0002.stage.0007.task.000030 state: DONE
# Update: pipeline.0002.stage.0007.task.000034 state: DONE
# Update: pipeline.0002.stage.0007.task.000027 state: DONE
# Update: pipeline.0002.stage.0007 state: DONE
# Update: pipeline.0002.stage.0008 state: SCHEDULING
# Update: pipeline.0002.stage.0008.task.000035 state: SCHEDULING
# Update: submit: pipeline.0002.stage.0008.task.000035 state: SCHEDULED
# ###Update: pipeline.0002.stage.0008 state: SCHEDULED
# Update: ##pipeline.0002.stage.0008.task.000035 state: SUBMITTING
# ###################################################################
# Update: pipeline.0003.stage.0010.task.000043 state: DONE
# Update: pipeline.0003.stage.0010.task.000037 state: DONE
# Update: pipeline.0003.stage.0010.task.000046 state: EXECUTED
# Update: pipeline.0003.stage.0010.task.000046 state: DONE
# Update: pipeline.0003.stage.0010.task.000038 state: EXECUTED
# Update: pipeline.0003.stage.0010.task.000038 state: DONE
# Update: pipeline.0003.stage.0010.task.000045 state: EXECUTED
# Update: pipeline.0003.stage.0010.task.000045 state: DONE
# Update: pipeline.0003.stage.0010.task.000044 state: DONE
# Update: pipeline.0003.stage.0010.task.000042 state: DONE
# Update: pipeline.0003.stage.0010.task.000039 state: DONE
# Update: pipeline.0003.stage.0010.task.000040 state: DONE
# Update: pipeline.0003.stage.0010.task.000041 state: DONE
# Update: pipeline.0003.stage.0010 state: DONE
# Update: pipeline.0003.stage.0011 state: SCHEDULING
# Update: pipeline.0003.stage.0011.task.000047 state: SCHEDULING
# Update: submit: pipeline.0003.stage.0011.task.000047 state: SCHEDULED
# Update: pipeline.0003.stage.0011 state: SCHEDULED
# Update: #pipeline.0003.stage.0011.task.000047 state: SUBMITTING
# #######################################################################
# Update: pipeline.0002.stage.0008.task.000035 state: DONE
# Update: pipeline.0002.stage.0008 state: DONE
# Update: pipeline.0002 state: DONE
# Update: pipeline.0003.stage.0011.task.000047 state: DONE
# Update: pipeline.0003.stage.0011 state: DONE
# Update: pipeline.0003 state: DONE
# close task manager                                                            ok
# closing session re.session.thinkie.merzky.019614.0028                          \
# close pilot manager                                                            \
# wait for 1 pilot(s)
#                                                                               ok
#                                                                               ok
# + re.session.thinkie.merzky.019614.0028 (json)
# + pilot.0000 (profiles)
# + pilot.0000 (logfiles)
# session lifetime: 54.2s                                                       ok
# All components terminated
#   0 --         96403690428765798
#   1 --          1143459396431088
